# %% [markdown]
# ![2.PNG](attachment:2.PNG)

# %% [markdown]
# When two independent variables are very strongly correlated, multiple regression may not be
# able to determine which is the important one. In this case, the variables are said to be
# collinear

# %% [markdown]
# **Model Selection**

# %% [markdown]
# There are many situations in which a large number of independent variables have been
# measured, and we need to decide which of them to include in a model. This is the problem of
# model selection, and it is a difficult one.

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG)

# %% [markdown]
# **Determining Whether Variables Can Be Dropped from a
# Model**

# %% [markdown]
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA.PNG)
