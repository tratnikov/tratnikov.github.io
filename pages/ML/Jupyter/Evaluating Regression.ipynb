# %% [markdown]
# ![1_G6aSSAJuMDF5RYvPeKqPzg.png](attachment:1_G6aSSAJuMDF5RYvPeKqPzg.png)

# %% [markdown]
# et residuals

# %% [markdown]
# https://www.youtube.com/watch?v=w2FKXOa0HGA&ab_channel=statisticsfun
# https://www.youtube.com/watch?v=8W2fGkU5LYU&ab_channel=BenLambert
# ![1__HbrAW-tMRBli6ASD5Bttw.png](attachment:1__HbrAW-tMRBli6ASD5Bttw.png)

# %% [markdown]
# ![%D0%91%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F.png](attachment:%D0%91%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F.png)

# %% [markdown]
# N -number of pints
#
# p - number of independent variables
#
# https://www.youtube.com/watch?v=8W2fGkU5LYU&ab_channel=BenLambert
