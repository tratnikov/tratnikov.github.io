# %% [markdown]
# ![Neuron3.png](attachment:0e7f858d-c579-4233-b08f-f889ceac2fdd.png)

# %% [markdown]
# ![A-hypothetical-example-of-Multilayer-Perceptron-Network.png](attachment:6c0e5ea1-e78b-4d4b-a9a0-0ee8d127f65c.png)

# %% [markdown]
# deep neural network if it consists of 2 hidden layers
#
# neural network can approximate any convex continious function

# %% [markdown]
# [Universal approximation theorem
# ](https://en.wikipedia.org/wiki/Universal_approximation_theorem)
#
# Use activation function to set boundries to output values from the neuron
#
# [Activation function](https://en.wikipedia.org/wiki/Activation_function)

# %% [markdown]
# **Multi-Class Classification**
#
# 1. mutually exclusive (photo has diffrent tags)
# 2. non-exclusive classes (but photo can be only colored or black&white)

# %% [markdown]
# ![76_blog_image_1.png](attachment:5beb5de5-8804-4724-a5f9-0e3100a928d9.png)
#
# non-exclusive sigmoid function
#
# for mutually exclusive softmax function as output layer

# %% [markdown]
# **Cost function or loss or error**
#
# To evaluate model prediction use cost function
# [Loss function](https://en.wikipedia.org/wiki/Loss_function)

# %% [markdown]
# ![The-basic-structure-of-an-artificial-neuron-43.png](attachment:5bd86398-fdd1-4ed5-8414-81cbeb0a35e1.png)
#
# **gradient descent to find minimum of cost function**

# %% [markdown]
# ![F1-02.large.jpg](attachment:12ab0c58-b8c3-4e88-80a6-0c514c2dd942.jpg)

# %% [markdown]
# **adaptive gradient descent change steps during searching minimum**
# a method of stochastic optimization  adam

# %% [markdown]
# ![Без названия.png](attachment:670c03be-f01c-44cf-abf7-0d35b3b41e14.png)

# %% [markdown]
# [Backpropagation](https://de.wikipedia.org/wiki/Backpropagation)

# %% [markdown]
# TensorFlow Google developed
# # Keras contains tensorflow
