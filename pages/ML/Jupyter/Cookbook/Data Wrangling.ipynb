# %%
# Load library
import pandas as pd
# Create URL
url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'
# Load data as a dataframe
dataframe = pd.read_csv(url)
# Show first 5 rows
dataframe.head(5)
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# **Creating a Data Frame**

# %%
# Load library
import pandas as pd
# Create DataFrame
dataframe = pd.DataFrame()
# Add columns
dataframe['Name'] = ['Jacky Jackson', 'Steven Stevenson']
dataframe['Age'] = [38, 25]
dataframe['Driver'] = [True, False]
# Show DataFrame
dataframe
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False

# %% [markdown]
# Alternatively, once we have created a DataFrame object, we can append new rows to
# the bottom:

# %%
# Create row
new_person = pd.Series(['Molly Mooney', 40, True], index=['Name','Age','Driver'])
# Append row
dataframe.append(new_person, ignore_index=True)
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False
# 2      Molly Mooney   40    True

# %% [markdown]
# **Describing the Data**

# %%
# Load library
import pandas as pd
# Create URL
url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'
# Load data as a dataframe
dataframe = pd.read_csv(url)
# Describe
dataframe.describe()
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# max                   6.000000  512.32920

# %% [markdown]
# **Navigating DataFrames**

# %%
# Select first row
dataframe.iloc[0]
# Out:
# Survived                                        0
# Pclass                                          3
# Name                       Mr. Owen Harris Braund
# Sex                                          male
# Age                                            22
# Siblings/Spouses Aboard                         1
# Parents/Children Aboard                         0
# Fare                                         7.25
# Name: 0, dtype: object

# %%
# Select three rows
dataframe.iloc[1:4]
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000

# %%
# Set index
dataframe = dataframe.set_index(dataframe['Name'])
# Show row
dataframe.loc['Miss. Laina Heikkinen']
# Out:
# Survived                                       1
# Pclass                                         3
# Name                       Miss. Laina Heikkinen
# Sex                                       female
# Age                                           26
# Siblings/Spouses Aboard                        0
# Parents/Children Aboard                        0
# Fare                                       7.925
# Name: Miss. Laina Heikkinen, dtype: object

# %% [markdown]
# **Selecting Rows Based on Conditionals**

# %%
# Filter rows
dataframe[(dataframe['Sex'] == 'female') & (dataframe['Age'] >= 50)]
# Out:
#                                                    Survived  Pclass  \
# Name
# Miss. Elizabeth Bonnell                                   1       1
# Mrs. (Mary D Kingcome) Hewlett                            1       2
# Miss. Ann Elizabeth Isham                                 0       1
# Miss. Elise Lurette                                       1       1
# Mrs. (Lutie Davis) Parrish                                1       2
# Mrs. Frank Manley (Anna Sophia Atkinson) Warren                          0
# Miss. Ellen Toomey                                                       0
# Mrs. (Hedwig) Turkula                                                    0
# Miss. Elizabeth Mussey Eustis                                            0
# Mrs. Martin (Elizabeth L. Barrett) Rothschild                            0
# Miss. Lucy Ridsdale                                                      0
# Miss. (Marion Ogden) Meanwell                                            0
# Mrs. Edward Dale (Charlotte Lamson) Appleton                             0
# Mrs. Walter Bertram (Martha Eustis) Stephenson                           0
# Mrs. John C (Anna Andrews) Hogeboom                                      0
# Mrs. (Mary) Mack                                                         0
# Mrs. Elizabeth (Eliza Needs) Hocking                                     3
# Mrs. Charles Melville (Clara Jennings Gregg) Hays                        1
# Mrs. George Nelson (Martha Evelyn) Stone                                 0
# Mrs. Thomas Jr (Lily Alexenia Wilson) Potter                             1
#
#                                                        Fare
# Name
# Miss. Elizabeth Bonnell                             26.5500
# Mrs. (Mary D Kingcome) Hewlett                      16.0000
# Miss. Ann Elizabeth Isham                           28.7125
# Miss. Elise Lurette                                146.5208
# Mrs. (Lutie Davis) Parrish                          26.0000
# Mrs. William Thompson (Edith Junkins) Graham       153.4625
# Miss. Kornelia Theodosia Andrews                    77.9583
# Mrs. James (Helene DeLaudeniere Chaput) Baxter     247.5208
# Mrs. Frank Manley (Anna Sophia Atkinson) Warren     75.2500
# Miss. Ellen Toomey                                  10.5000
# Mrs. (Hedwig) Turkula                                9.5875
# Miss. Elizabeth Mussey Eustis                       78.2667
# Mrs. Martin (Elizabeth L. Barrett) Rothschild       59.4000
# Miss. Lucy Ridsdale                                 10.5000
# Miss. (Marion Ogden) Meanwell                        8.0500
# Mrs. Edward Dale (Charlotte Lamson) Appleton        51.4792
# Mrs. Walter Bertram (Martha Eustis) Stephenson      78.2667
# Mrs. John C (Anna Andrews) Hogeboom                 77.9583
# Mrs. (Mary) Mack                                    10.5000
# Mrs. Elizabeth (Eliza Needs) Hocking                23.0000
# Mrs. Charles Melville (Clara Jennings Gregg) Hays   93.5000
# Mrs. George Nelson (Martha Evelyn) Stone            80.0000
# Mrs. Thomas Jr (Lily Alexenia Wilson) Potter        83.1583

# %% [markdown]
# **Replacing Values**

# %%
dataframe['Sex'].replace("female", "Woman").head(2)
# Out:
# Name
# Mr. Owen Harris Braund                                 male
# Mrs. John Bradley (Florence Briggs Thayer) Cumings    Woman
# Name: Sex, dtype: object

# %%
dataframe['Sex'].replace(["female", "male"], ["Woman", "Man"]).head(5)
# Out:
# Name
# Mr. Owen Harris Braund                                  Man
# Mrs. John Bradley (Florence Briggs Thayer) Cumings    Woman
# Miss. Laina Heikkinen                                 Woman
# Mrs. Jacques Heath (Lily May Peel) Futrelle           Woman
# Mr. William Henry Allen                                 Man
# Name: Sex, dtype: object

# %%
# Replace values, show two rows
dataframe.replace(1, "One").head(2)
# Out:
#                                                    Survived Pclass  \
# Name
# Mr. Owen Harris Braund                                    0      3
# Mrs. John Bradley (Florence Briggs Thayer) Cumings      One    One
#
#                                                                                                  Name  \
# Name
# Mr. Owen Harris Braund                                                         Mr. Owen Harris Braund
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#                                                        Sex Age  \
# Name
# Mr. Owen Harris Braund                                male  22
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  female  38
#
#                                                    Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                 One
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                     One
#
#                                                    Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                   0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                       0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833

# %%
#replace also accepts regular expressions:
# Replace values, show two rows
dataframe.replace(r"1st", "First", regex=True).head(2)
# Out:
#                                                     Survived  Pclass  \
# Name
# Mr. Owen Harris Braund                                     0       3
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1
#
#                                                                                                  Name  \
# Name
# Mr. Owen Harris Braund                                                         Mr. Owen Harris Braund
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#                                                        Sex   Age  \
# Name
# Mr. Owen Harris Braund                                male  22.0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  female  38.0
#
#                                                     Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                    1
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        1
#
#                                                     Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                    0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833

# %% [markdown]
# **Renaming columns**

# %%
dataframe.rename(columns={'Pclass': 'Passenger Class', 'Sex': 'Gender'}).head(2)
# Out:
#                                                     Survived  Passenger Class  \
# Name
# Mr. Owen Harris Braund                                     0                3
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1                1
#
#                                                                                                  Name  \
# Name
# Mr. Owen Harris Braund                                                         Mr. Owen Harris Braund
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#                                                     Gender   Age  \
# Name
# Mr. Owen Harris Braund                                male  22.0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  female  38.0
#
#                                                     Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                    1
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        1
#
#                                                     Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                    0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833

# %%
#Rename multiple
import collections
column_names = collections.defaultdict(str)
# Create keys
for name in dataframe.columns:
    column_names[name]
# Show dictionary
column_names
# Out:
# defaultdict(str,
#             {'Survived': '',
#              'Pclass': '',
#              'Name': '',
#              'Sex': '',
#              'Age': '',
#              'Siblings/Spouses Aboard': '',
#              'Parents/Children Aboard': '',
#              'Fare': ''})

# %% [markdown]
# **Finding the Minimum, Maximum, Sum, Average, and
# Count**

# %%
print('Maximum:', dataframe['Age'].max())
print('Minimum:', dataframe['Age'].min())
print('Mean:', dataframe['Age'].mean())
print('Sum:', dataframe['Age'].sum())
print('Count:', dataframe['Age'].count())
# Out:
# Maximum: 80.0
# Minimum: 0.42
# Mean: 29.471443066516347
# Sum: 26141.17
# Count: 887

# %% [markdown]
# In addition to the statistics used in the solution, pandas offers variance (var), standard
# deviation (std), kurtosis (kurt), skewness (skew), standard error of the mean
# (sem), mode (mode), median (median), and a number of others.

# %% [markdown]
# **Finding unique value**

# %%
dataframe['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
dataframe['Sex'].value_counts()
# Out:
# male      573
# female    314
# Name: Sex, dtype: int64

# %%
dataframe['Pclass'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Handling Missing Values**

# %%
## Select missing values, show two rows
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 887 entries, Mr. Owen Harris Braund to Mr. Patrick Dooley
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 102.4+ KB

# %%
import numpy as np
# Replace values with NaN
dataframe['Sex'] = dataframe['Sex'].replace('male', np.nan)

# %%
values used to indicate missing values:
# Load data, set missing values
dataframe = pd.read_csv(url, na_values=[np.nan, 'NONE', -999])
# Out:
#   File "<ipython-input-21-264cd689ac1d>", line 1
#     values used to indicate missing values:
#            ^
# SyntaxError: invalid syntax

# %%
Oftentimes a dataset uses a specific value to denote a missing observation, such as
NONE, -999, or .. pandas’ read_csv includes a parameter allowing us to specify the

# %% [markdown]
# **Deleting a column**

# %%
# Delete column
dataframe.drop(['Age', 'Sex'], axis=1).head(2)
# Out:
#                                                     Survived  Pclass  \
# Name
# Mr. Owen Harris Braund                                     0       3
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1
#
#                                                                                                  Name  \
# Name
# Mr. Owen Harris Braund                                                         Mr. Owen Harris Braund
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#                                                     Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                    1
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        1
#
#                                                     Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                    0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833

# %%
#Deleting multiple
new_df=dataframe.drop(dataframe.columns[:4], axis=1)

# %%
new_df
# Out:
#                                                      Age  \
# Name
# Mr. Owen Harris Braund                              22.0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  38.0
# Miss. Laina Heikkinen                               26.0
# Mrs. Jacques Heath (Lily May Peel) Futrelle         35.0
# Mr. William Henry Allen                             35.0
# ...                                                  ...
# Rev. Juozas Montvila                                27.0
# Miss. Margaret Edith Graham                         19.0
# Miss. Catherine Helen Johnston                       7.0
# Mr. Karl Howell Behr                                26.0
# Mr. Patrick Dooley                                  32.0
#
#                                                     Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                    1
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        1
# Miss. Laina Heikkinen                                                     0
# Mrs. Jacques Heath (Lily May Peel) Futrelle                               1
# Mr. William Henry Allen                                                   0
# ...                                                                     ...
# Rev. Juozas Montvila                                                      0
# Miss. Margaret Edith Graham                                               0
# Miss. Catherine Helen Johnston                                            1
# Mr. Karl Howell Behr                                                      0
# Mr. Patrick Dooley                                                        0
#
#                                                     Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                    0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
# Miss. Laina Heikkinen                                                     0
# Mrs. Jacques Heath (Lily May Peel) Futrelle                               0
# Mr. William Henry Allen                                                   0
# ...                                                                     ...
# Rev. Juozas Montvila                                                      0
# Miss. Margaret Edith Graham                                               0
# Miss. Catherine Helen Johnston                                            2
# Mr. Karl Howell Behr                                                      0
# Mr. Patrick Dooley                                                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings

# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
# Miss. Laina Heikkinen                                                     0
# Mrs. Jacques Heath (Lily May Peel) Futrelle                               0
# Mr. William Henry Allen                                                   0
# ...                                                                     ...
# Rev. Juozas Montvila                                                      0
# Miss. Margaret Edith Graham                                               0
# Miss. Catherine Helen Johnston                                            2
# Mr. Karl Howell Behr                                                      0
# Mr. Patrick Dooley                                                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833
# Miss. Laina Heikkinen                                7.9250
# Mrs. Jacques Heath (Lily May Peel) Futrelle         53.1000
# Mr. William Henry Allen                              8.0500
# ...                                                     ...
# Rev. Juozas Montvila                                13.0000
# Miss. Margaret Edith Graham                         30.0000
# Miss. Catherine Helen Johnston                      23.4500
# Mr. Karl Howell Behr                                30.0000
# Mr. Patrick Dooley                                   7.7500
#
# [887 rows x 8 columns]

# %%
dataframe.drop_duplicates(subset=['Sex'])
# Out:
#                                                     Survived  Pclass  \
# Name
# Mr. Owen Harris Braund                                     0       3
# Mrs. John Bradley (Florence Briggs Thayer) Cumings         1       1
#
#                                                                                                  Name  \
# Name
# Mr. Owen Harris Braund                                                         Mr. Owen Harris Braund
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  Mrs. John Bradley (Florence Briggs Thayer) Cum...
#
#                                                        Sex   Age  \
# Name
# Mr. Owen Harris Braund                                 NaN  22.0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  female  38.0
#
#                                                     Siblings/Spouses Aboard  \
# Name
# Mr. Owen Harris Braund                                                    1
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        1
#
#                                                     Parents/Children Aboard  \
# Name
# Mr. Owen Harris Braund                                                    0
# Mrs. John Bradley (Florence Briggs Thayer) Cumings                        0
#
#                                                        Fare
# Name
# Mr. Owen Harris Braund                               7.2500
# Mrs. John Bradley (Florence Briggs Thayer) Cumings  71.2833

# %%
dataframe.drop_duplicates(subset=['Sex'], keep='last')
# Out:
#                                 Survived  Pclass  \
# Name
# Miss. Catherine Helen Johnston         0       3
# Mr. Patrick Dooley                     0       3
#
#                                                           Name     Sex   Age  \
# Name
# Miss. Catherine Helen Johnston  Miss. Catherine Helen Johnston  female   7.0
# Mr. Patrick Dooley                          Mr. Patrick Dooley     NaN  32.0
#
#                                 Siblings/Spouses Aboard  \
# Name
# Miss. Catherine Helen Johnston                        1
# Mr. Patrick Dooley                                    0
#
#                                 Parents/Children Aboard   Fare
# Name
# Miss. Catherine Helen Johnston                        2  23.45
# Mr. Patrick Dooley                                    0   7.75

# %% [markdown]
# **Grouping Rows by Values**

# %%
dataframe.groupby('Sex').mean()
# Out:
#         Survived    Pclass        Age  Siblings/Spouses Aboard  \
# Sex
# female  0.742038  2.159236  27.719745                 0.694268
#
#         Parents/Children Aboard       Fare
# Sex
# female                 0.649682  44.479818

# %%
dataframe = pd.read_csv(url)
dataframe.groupby(['Sex','Survived'])['Age'].mean()
# Out:
# Sex     Survived
# female  0           24.419753
#         1           28.866953
# male    0           31.136853
#         1           27.428165
# Name: Age, dtype: float64

# %% [markdown]
# **Grouping Rows by Time**

# %%
import pandas as pd
import numpy as np
# Create date range
time_index = pd.date_range('06/06/2017', periods=1000000, freq='30S')

# %%
time_index
# Out:
# DatetimeIndex(['2017-06-06 00:00:00', '2017-06-06 00:00:30',
#                '2017-06-06 00:01:00', '2017-06-06 00:01:30',
#                '2017-06-06 00:02:00', '2017-06-06 00:02:30',
#                '2017-06-06 00:03:00', '2017-06-06 00:03:30',
#                '2017-06-06 00:04:00', '2017-06-06 00:04:30',
#                ...
#                '2018-05-19 05:15:00', '2018-05-19 05:15:30',
#                '2018-05-19 05:16:00', '2018-05-19 05:16:30',
#                '2018-05-19 05:17:00', '2018-05-19 05:17:30',
#                '2018-05-19 05:18:00', '2018-05-19 05:18:30',
#                '2018-05-19 05:19:00', '2018-05-19 05:19:30'],
#               dtype='datetime64[ns]', length=1000000, freq='30S')

# %%
# Create DataFrame
dataframe = pd.DataFrame(index=time_index)

# %%
# Create column of random values
dataframe['Sale_Amount'] = np.random.randint(1, 10, 1000000)

# %%
# Group rows by week, calculate sum per week
dataframe.resample('W').sum()
# Out:
#             Sale_Amount
# 2017-06-11        86429
# 2017-06-18       100839
# 2017-06-25       100389
# 2017-07-02       100679
# 2017-07-09       101354
# 2017-07-16       101035
# 2017-07-23       100663
# 2017-07-30       100890
# 2017-08-06        99967
# 2017-08-13       100624
# 2017-08-20       100884
# 2017-08-27       100130
# 2017-09-03       100406
# 2017-09-10       100460
# 2017-09-17       101753
# 2017-09-24       100535
# 2017-10-01       100815
# 2017-10-08       100936
# 2017-10-15       100838
# 2017-10-22       101129
# 2017-10-29       100938
# 2017-11-05       101080
# 2017-11-12       100968
# 2017-11-19       101138
# 2017-11-26       100935
# 2017-12-03       100543
# 2017-12-10       100242
# 2017-12-17       100869
# 2017-12-24       100613
# 2017-12-31       100415
# 2018-01-07       101446
# 2018-01-14       100494
# 2018-01-21       100537
# 2018-01-28       100800
# 2018-02-04       100985
# 2018-02-11       100253
# 2018-02-18       100743
# 2018-02-25       100685
# 2018-03-04       101164
# 2018-03-11       101207
# 2018-03-18       101199
# 2018-03-25       100779
# 2018-04-01       100372
# 2018-04-08       100241
# 2018-04-15       100972
# 2018-04-22       101074
# 2018-04-29       100255
# 2018-05-06       100893
# 2018-05-13       100835
# 2018-05-20        75403

# %%
dataframe.resample('Q').sum()
# Out:
#             Sale_Amount
# 2017-06-30       359405
# 2017-09-30      1324029
# 2017-12-31      1325062
# 2018-03-31      1296553
# 2018-06-30       693784

# %%
dataframe.resample('M').sum()
# Out:
#             Sale_Amount
# 2017-06-30       359405
# 2017-07-31       446816
# 2017-08-31       445231
# 2017-09-30       431982
# 2017-10-31       447047
# 2017-11-30       433286
# 2017-12-31       444729
# 2018-01-31       446475
# 2018-02-28       402935
# 2018-03-31       447143
# 2018-04-30       430929
# 2018-05-31       262855

# %%
dataframe.resample('17min').sum()
# Out:
#                      Sale_Amount
# 2017-06-06 00:00:00          176
# 2017-06-06 00:17:00          161
# 2017-06-06 00:34:00          179
# 2017-06-06 00:51:00          166
# 2017-06-06 01:08:00          178
# ...                          ...
# 2018-05-19 03:59:00          178
# 2018-05-19 04:16:00          179
# 2018-05-19 04:33:00          141
# 2018-05-19 04:50:00          176
# 2018-05-19 05:07:00          135
#
# [29412 rows x 1 columns]

# %%
dataframe.resample('Q').sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataframe.resample('M').sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
dataframe.resample('2W').std()
# Out:
#             Sale_Amount
# 2017-06-11     2.584740
# 2017-06-25     2.579429
# 2017-07-09     2.576975
# 2017-07-23     2.575990
# 2017-08-06     2.579711
# 2017-08-20     2.587614
# 2017-09-03     2.588870
# 2017-09-17     2.581049
# 2017-10-01     2.582311
# 2017-10-15     2.579172
# 2017-10-29     2.591980
# 2017-11-12     2.588569
# 2017-11-26     2.587354
# 2017-12-10     2.586860
# 2017-12-24     2.575556
# 2018-01-07     2.578144
# 2018-01-21     2.581536
# 2018-02-04     2.581234
# 2018-02-18     2.589057
# 2018-03-04     2.592687
# 2018-03-18     2.578069
# 2018-04-01     2.568721
# 2018-04-15     2.580989
# 2018-04-29     2.583630
# 2018-05-13     2.582730
# 2018-05-27     2.566805

# %% [markdown]
# **Concatenating**

# %%
# Load library
import pandas as pd
data_a = {'id': ['1', '2', '3'],
'first': ['Alex', 'Amy', 'Allen'],
'last': ['Anderson', 'Ackerman', 'Ali']}
dataframe_a = pd.DataFrame(data_a, columns = ['id', 'first', 'last'])
# Create DataFrame
data_b = {'id': ['4', '5', '6'],
'first': ['Billy', 'Brian', 'Bran'],
'last': ['Bonder', 'Black', 'Balwner']}
dataframe_b = pd.DataFrame(data_b, columns = ['id', 'first', 'last'])
# Concatenate DataFrames by rows
pd.concat([dataframe_a, dataframe_b], axis=0)
# Out:
#   id  first      last
# 0  1   Alex  Anderson
# 1  2    Amy  Ackerman
# 2  3  Allen       Ali
# 0  4  Billy    Bonder
# 1  5  Brian     Black
# 2  6   Bran   Balwner

# %%
pd.concat([dataframe_a, dataframe_b], axis=1)
# Out:
#   id  first      last id  first     last
# 0  1   Alex  Anderson  4  Billy   Bonder
# 1  2    Amy  Ackerman  5  Brian    Black
# 2  3  Allen       Ali  6   Bran  Balwner

# %% [markdown]
# **Meerging**

# %%
import pandas as pd
# Create DataFrame
employee_data = {'employee_id': ['1', '2', '3', '4'],
'name': ['Amy Jones', 'Allen Keys', 'Alice Bees',
'Tim Horton']}
dataframe_employees = pd.DataFrame(employee_data, columns = ['employee_id',
'name'])
# Create DataFrame
sales_data = {'employee_id': ['3', '4', '5', '6'],
'total_sales': [23456, 2512, 2345, 1455]}
dataframe_sales = pd.DataFrame(sales_data, columns = ['employee_id',
'total_sales'])
# Merge DataFrames
pd.merge(dataframe_employees, dataframe_sales, on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512

# %%
# Merge DataFrames
pd.merge(dataframe_employees, dataframe_sales, on='employee_id', how='outer')
# Out:
#   employee_id        name  total_sales
# 0           1   Amy Jones          NaN
# 1           2  Allen Keys          NaN
# 2           3  Alice Bees      23456.0
# 3           4  Tim Horton       2512.0
# 4           5         NaN       2345.0
# 5           6         NaN       1455.0

# %%
# Merge DataFrames
pd.merge(dataframe_employees,
dataframe_sales,
left_on='employee_id',
right_on='employee_id')
# Out:
#   employee_id        name  total_sales
# 0           3  Alice Bees        23456
# 1           4  Tim Horton         2512
