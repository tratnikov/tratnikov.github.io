# %%
#Radiobutton
from tkinter import *
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg,NavigationToolbar2Tk
import matplotlib


root = Tk()
root.title("Data quality")
root.iconbitmap('icon.ico')


def _quit():
    root.quit()     # stops mainloop
    root.destroy()  # this is necessary on Windows to prevent
                    # Fatal Python Error: PyEval_RestoreThread: NULL tstate
        

            
def plot(x,y):
    ax.plot(x,y)
    canvas.draw()

def click(val):
    ax.clear()
    if val==1:
        y=[1,2,3]
        x=[1,2,3]
        plot(x,y)
    else:
        y=[5,4,3]
        x=[1,2,3]
        plot(x,y)



fig,ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, root)
canvas.draw()
canvas.get_tk_widget().grid(row=2,column=0)
toolbarFrame = Frame(master=root)
toolbarFrame.grid(row=3,column=0)
toolbar = NavigationToolbar2Tk(canvas, toolbarFrame)


r =IntVar()
Radiobutton(root,text="Option 1",variable=r,value=1,command=lambda: click(r.get())).grid(row=0,column=0)
Radiobutton(root,text="Option 2",variable=r,value=2,command=lambda: click(r.get())).grid(row=1,column=0)
Button(master=root, text="Exit", command=_quit).grid(row=4,column=0)



mainloop()

# %%
#Listbox
from tkinter import *
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg,NavigationToolbar2Tk
import matplotlib


root = Tk()
root.title("Data quality")
root.iconbitmap('icon.ico')
root.resizable(0, 0)
my_list=Listbox(root)
my_list.grid(row=5,column=0)

my_list2 = [
    '1',
    '2',
    '3',
    '4'
]

for item in my_list2:
    my_list.insert(END,item)

    
               
def plot(x,y):
    ax.plot(x,y)
    canvas.draw()

def click(val):
    ax.clear()
    if val==1:
        y=[1,2,3]
        x=[1,2,3]
        plot(x,y)
    elif val==2:
        y=[5,4,3]
        x=[1,2,3]
        plot(x,y)
    else:
        y=[9,9,9]
        x=[1,2,3]
        plot(x,y)


fig,ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, root)
canvas.draw()
canvas.get_tk_widget().grid(row=2,column=0)
toolbarFrame = Frame(master=root)
toolbarFrame.grid(row=3,column=0)
toolbar = NavigationToolbar2Tk(canvas, toolbarFrame)


Button(master=root, text="Exit", command=_quit).grid(row=4,column=0)
Button(master=root, text="Plot",command=lambda:click(int(my_list.get(ACTIVE)))).grid(row=6,column=0)



root.mainloop()

# %%
#Clear canvas
from tkinter import *
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg,NavigationToolbar2Tk
import matplotlib


root = Tk()
root.title("Data quality")
root.iconbitmap('icon.ico')
root.resizable(0, 0)
my_list=Listbox(root)
my_list.grid(row=6,column=0)

my_list2 = [
    '1',
    '2',
    '3',
    '4'
]

for item in my_list2:
    my_list.insert(END,item)

    
               
def plot(x,y):
    ax.plot(x,y)
    canvas.draw()

def click(val):
    if val==1:
        y=[1,2,3]
        x=[1,2,3]
        plot(x,y)
    elif val==2:
        y=[5,4,3]
        x=[1,2,3]
        plot(x,y)
    else:
        y=[9,9,9]
        x=[1,2,3]
        plot(x,y)

def _clear():
    ax.clear()
    canvas.draw()

        
fig,ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, root)
canvas.draw()
canvas.get_tk_widget().grid(row=2,column=0)
toolbarFrame = Frame(master=root)
toolbarFrame.grid(row=3,column=0)
toolbar = NavigationToolbar2Tk(canvas, toolbarFrame)


Button(master=root, text="Plot",command=lambda:click(int(my_list.get(ACTIVE)))).grid(row=4,column=0)
Button(master=root, text="Clear", command=_clear).grid(row=5,column=0)
Button(master=root, text="Exit", command=_quit).grid(row=7,column=0)


root.mainloop()

# %%
#Dropbox
from tkinter import *
from tkinter import ttk
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg,NavigationToolbar2Tk
import matplotlib


root = Tk()
root.title("Data quality")
root.iconbitmap('icon.ico')
root.resizable(0, 0)


def _quit():
    root.quit()     # stops mainloop
    root.destroy()  # this is necessary on Windows to prevent
                    # Fatal Python Error: PyEval_RestoreThread: NULL tstate    
               
def plot(x,y):
    ax.plot(x,y)
    canvas.draw()

def click(val):
    if val==1:
        y=[1,2,3]
        x=[1,2,3]
        plot(x,y)
    elif val==2:
        y=[5,4,3]
        x=[1,2,3]
        plot(x,y)
    else:
        y=[9,9,9]
        x=[1,2,3]
        plot(x,y)

def _clear():
    ax.clear()
    canvas.draw()

        
fig,ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, root)
canvas.draw()
canvas.get_tk_widget().grid(row=2,column=0)
toolbarFrame = Frame(master=root)
toolbarFrame.grid(row=3,column=0)
toolbar = NavigationToolbar2Tk(canvas, toolbarFrame)



option = [
    '1',
    '2',
    '3',
    '4',  
]

clicked = StringVar();
clicked.set(option[0]);



combo = ttk.Combobox(root,value=option)
combo.current(0)
combo.grid(row=8,column=0)

Button(master=root, text="Plot",command=lambda:click(int(combo.get()))).grid(row=4,column=0)
Button(master=root, text="Clear", command=_clear).grid(row=5,column=0)
Button(master=root, text="Exit", command=_quit).grid(row=7,column=0)


root.mainloop()

# %%
#Axis selection
from tkinter import *
from tkinter import ttk
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg,NavigationToolbar2Tk
import matplotlib


root = Tk()
root.title("Data quality")
root.iconbitmap('icon.ico')
root.resizable(0, 0)


def _quit():
    root.quit()     # stops mainloop
    root.destroy()  # this is necessary on Windows to prevent
                    # Fatal Python Error: PyEval_RestoreThread: NULL tstate    
               
def plot(x,y):
    ax.plot(x,y)
    canvas.draw()

def click(val):
    if val==1:
        y=[1,2,3]
        x=[1,2,3]
        plot(x,y)
    elif val==2:
        y=[5,4,3]
        x=[1,2,3]
        plot(x,y)
    elif val==3:
        y=[9,6,1]
        x=[1,2,3]
        plot(x,y)
    else:
        y=[2,2,2]
        x=[1,2,3]
        plot(x,y)

def _clear():
    ax.clear()
    canvas.draw()

    
def change_axis(geg1,geg2):
    ax.set_xlim([geg1, geg2])
    canvas.draw()
        
fig,ax = plt.subplots()
canvas = FigureCanvasTkAgg(fig, root)
canvas.draw()
canvas.get_tk_widget().grid(row=2,column=0)
toolbarFrame = Frame(master=root)
toolbarFrame.grid(row=3,column=0)
toolbar = NavigationToolbar2Tk(canvas, toolbarFrame)



option = [
    '1',
    '2',
    '3',
    '4',  
]

clicked = StringVar();
clicked.set(option[0]);




combo = ttk.Combobox(root,value=option)
combo.current(0)
combo.grid(row=8,column=0)

Button(master=root, text="Plot",command=lambda:click(int(combo.get()))).grid(row=4,column=0)
Button(master=root, text="Clear", command=_clear).grid(row=5,column=0)
Button(master=root, text="Exit", command=_quit).grid(row=11,column=0)

e1 = Entry(root)
e1.grid(row=9,column=0)
e1.insert(0,"0")

e2 = Entry(root)
e2.grid(row=10,column=0)
e2.insert(0,"1")


Button(master=root, text="Change axis scale", command=lambda:change_axis(int(e1.get()),int(e2.get()))).grid(row=7,column=0)

root.mainloop()
